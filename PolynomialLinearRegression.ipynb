# %% [markdown]
# <a href="https://colab.research.google.com/github/TirilaPatricGabriel/ML/blob/main/PolynomialLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
polynomial_features = PolynomialFeatures(degree=4)
lr = LinearRegression()
X_pol = polynomial_features.fit_transform(X)
lr.fit(X_pol, y)
# Out:
# LinearRegression()

# %%
lr.predict(polynomial_features.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
pf = PolynomialFeatures(degree=4)
pf.fit(X)
X_poly = pf.transform(X)
lr = LinearRegression()
lr.fit(X_poly, y)

predicted_value = lr.predict(pf.transform([[6.5]]))

plt.scatter(X, y, color='red', label='Actual Data')

X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(-1, 1)
plt.plot(X_grid, lr.predict(pf.transform(X_grid)), color='blue')

plt.scatter([6.5], predicted_value, color='green')
# Out:
# <ipython-input-19-84ae92b5f04f>:21: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)
