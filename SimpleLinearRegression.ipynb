# %% [markdown]
# <a href="https://colab.research.google.com/github/TirilaPatricGabriel/ML/blob/main/SimpleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Salary_Data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

print(X)
print(y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3)

print(X_train)
print(y_train)
print(X_test)
print(y_test)
# Out:
# [[ 1.1]
#  [ 9. ]
#  [ 8.2]
#  [ 5.1]
#  [10.5]
#  [ 4.9]
#  [ 3.9]
#  [ 5.3]
#  [ 1.5]
#  [ 1.3]
#  [ 5.9]
#  [ 7.9]
#  [ 3.2]
#  [ 4. ]
#  [ 9.5]
#  [10.3]
#  [ 6. ]
#  [ 3.2]
#  [ 4. ]
#  [ 8.7]]
# [ 39343. 105582. 113812.  66029. 121872.  67938.  63218.  83088.  37731.
#   46205.  81363. 101302.  64445.  56957. 116969. 122391.  93940.  54445.
#   55794. 109431.]
# [[9.6]
#  [2. ]
#  [2.2]
#  [2.9]
#  [3.7]
#  [4.5]
#  [7.1]
#  [4.1]
#  [6.8]
#  [3. ]]
# [112635.  43525.  39891.  56642.  57189.  61111.  98273.  57081.  91738.
#   60150.]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([116642.59379168,  45870.92173645,  47733.33415896,  54251.77763773,
#         61701.42732775,  69151.07701778,  93362.43851035,  65426.25217277,
#         90568.8198766 ,  55182.98384898])

# %% [markdown]
# # Full code

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv('Salary_Data.csv')
# print(dataset)
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)

predictions = lr.predict(X_test)

results = pd.DataFrame({
    "Predictions": predictions,
    "Actual": y_test
})

print(results)

plt.scatter(X_test, y_test, color='red')
plt.plot(X_test, predictions, color='blue')
plt.show()
# Out:
#      Predictions    Actual
# 0  116494.820216  112635.0
# 1   81819.686444   81363.0
# 2   53704.713115   56642.0
# 3   45270.221117   43525.0
# 4   82756.852222   93940.0
# 5   56516.210448   54445.0
# 6   47144.552672   39891.0
# 7   74322.360223   66029.0
